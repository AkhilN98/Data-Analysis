# %%
import pandas as pd
import os

# %%
stats = pd.read_csv('C:\\Users\\akhil\\OneDrive\\Desktop\\PythonT\\Demographic-Data.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\akhil\\OneDrive\\Desktop\\PythonT'

# %%
len(stats)
# Out:
# 195

# %%
stats.head(10)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244         78.9000
# 1           Afghanistan          AFG      35.253          5.9000
# 2                Angola          AGO      45.985         19.1000
# 3               Albania          ALB      12.877         57.2000
# 4  United Arab Emirates          ARE      11.044         88.0000
# 5             Argentina          ARG      17.716         59.9000
# 6               Armenia          ARM      13.308         41.9000
# 7   Antigua and Barbuda          ATG      16.447         63.4000
# 8             Australia          AUS      13.200         83.0000
# 9               Austria          AUT       9.400         80.6188
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# ...

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
stats[21:31]
# Out:
#                 Country Name Country Code  Birth rate  Internet users  \
# 21                    Belize          BLZ      23.092           33.60
# 22                   Bermuda          BMU      10.400           95.30
# 23                   Bolivia          BOL      24.236           36.94
# 24                    Brazil          BRA      14.931           51.04
# 25                  Barbados          BRB      12.188           73.00
# 26         Brunei Darussalam          BRN      16.405           64.50
# 27                    Bhutan          BTN      18.134           29.90
# 28                  Botswana          BWA      25.267           15.00
# 29  Central African Republic          CAF      34.076            3.50
# 30                    Canada          CAN      10.900           85.80
#
#            Income Group
# 21  Upper middle income
# 22          High income
# 23  Lower middle income
# 24  Upper middle income
# 25          High income
# 26          High income
# ...

# %%
stats[100:121]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 100             Libya          LBY      21.425         16.5000
# 101         St. Lucia          LCA      15.430         46.2000
# 102     Liechtenstein          LIE       9.200         93.8000
# 103         Sri Lanka          LKA      17.863         21.9000
# 104           Lesotho          LSO      28.738          5.0000
# 105         Lithuania          LTU      10.100         68.4529
# 106        Luxembourg          LUX      11.300         93.7765
# 107            Latvia          LVA      10.200         75.2344
# 108  Macao SAR, China          MAC      11.256         65.8000
# 109           Morocco          MAR      21.023         56.0000
# 110           Moldova          MDA      12.141         45.0000
# 111        Madagascar          MDG      34.686          3.0000
# 112          Maldives          MDV      21.447         44.1000
# 113            Mexico          MEX      19.104         43.4600
# ...

# %%
stats[::-1]
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 194              Zimbabwe          ZWE      35.715            18.5
# 193                Zambia          ZMB      40.471            15.4
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 191          South Africa          ZAF      20.850            46.5
# 190           Yemen, Rep.          YEM      32.947            20.0
# ..                    ...          ...         ...             ...
# 4    United Arab Emirates          ARE      11.044            88.0
# 3                 Albania          ALB      12.877            57.2
# 2                  Angola          AGO      45.985            19.1
# 1             Afghanistan          AFG      35.253             5.9
# 0                   Aruba          ABW      10.244            78.9
#
#             Income Group
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ...

# %%
stats[::20]
# Out:
#     Country Name Country Code  Birth rate  Internet users         Income Group
# 0          Aruba          ABW      10.244         78.9000          High income
# 20       Belarus          BLR      12.500         54.1700  Upper middle income
# 40    Costa Rica          CRI      15.022         45.9600  Upper middle income
# 60         Gabon          GAB      30.555          9.2000  Upper middle income
# 80         India          IND      20.291         15.1000  Lower middle income
# 100        Libya          LBY      21.425         16.5000  Upper middle income
# 120   Mozambique          MOZ      39.705          5.4000           Low income
# 140       Poland          POL       9.600         62.8492          High income
# 160     Suriname          SUR      18.455         37.4000  Upper middle income
# 180      Uruguay          URY      14.374         57.6900          High income

# %%
stats['Country Name']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: Country Name, Length: 195, dtype: object

# %%
stats[['Country Name','Country Code','Birth rate']].head(11)
# Out:
#             Country Name Country Code  Birth rate
# 0                  Aruba          ABW      10.244
# 1            Afghanistan          AFG      35.253
# 2                 Angola          AGO      45.985
# 3                Albania          ALB      12.877
# 4   United Arab Emirates          ARE      11.044
# 5              Argentina          ARG      17.716
# 6                Armenia          ARM      13.308
# 7    Antigua and Barbuda          ATG      16.447
# 8              Australia          AUS      13.200
# 9                Austria          AUT       9.400
# 10            Azerbaijan          AZE      18.300

# %%
stats.columns = ['CountryName','CountryCode','BirthRate','InternerUsers','IncomeGroup']

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternerUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats.BirthRate
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
stats[['CountryName','BirthRate','InternerUsers']][11:51]
# Out:
#                  CountryName  BirthRate  InternerUsers
# 11                   Burundi     44.151       1.300000
# 12                   Belgium     11.200      82.170200
# 13                     Benin     36.440       4.900000
# 14              Burkina Faso     40.551       9.100000
# 15                Bangladesh     20.142       6.630000
# 16                  Bulgaria      9.200      53.061500
# 17                   Bahrain     15.040      90.000040
# 18              Bahamas, The     15.339      72.000000
# 19    Bosnia and Herzegovina      9.062      57.790000
# 20                   Belarus     12.500      54.170000
# 21                    Belize     23.092      33.600000
# 22                   Bermuda     10.400      95.300000
# 23                   Bolivia     24.236      36.940000
# 24                    Brazil     14.931      51.040000
# 25                  Barbados     12.188      73.000000
# 26         Brunei Darussalam     16.405      64.500000
# ...

# %%
###Filtering the Data

# %%
IU15 = stats.InternerUsers < 15

# %%
stats[IU15]
# Out:
#                   CountryName CountryCode  BirthRate  InternerUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 15                 Bangladesh         BGD     20.142           6.63
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 46                   Djibouti         DJI     25.486           9.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# ...

# %%
stats[(stats.BirthRate > 30) & (stats.InternerUsers < 10)]
# Out:
#                   CountryName CountryCode  BirthRate  InternerUsers  \
# 1                 Afghanistan         AFG     35.253           5.90
# 11                    Burundi         BDI     44.151           1.30
# 13                      Benin         BEN     36.440           4.90
# 14               Burkina Faso         BFA     40.551           9.10
# 29   Central African Republic         CAF     34.076           3.50
# 34              Cote d'Ivoire         CIV     37.320           8.40
# 35                   Cameroon         CMR     37.236           6.40
# 36                Congo, Rep.         COG     37.011           6.60
# 38                    Comoros         COM     34.326           6.50
# 52                    Eritrea         ERI     34.800           0.90
# 55                   Ethiopia         ETH     32.925           1.90
# 60                      Gabon         GAB     30.555           9.20
# 64                     Guinea         GIN     37.337           1.60
# ...

# %%
stats[stats.CountryName == 'Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternerUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
###SeaBorn Package

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline
plt.rcParams['figure.figsize'] = 10,8

# %%
#Distribution:

vis1 = sns.distplot(stats["InternerUsers"])

# %%
vis1 = sns.distplot(stats["InternerUsers"], bins = 25)

# %%
vis2 = sns.boxplot(data= stats, x = 'IncomeGroup', y = 'BirthRate' )

# %%
###Seaborn Gallery

# %% [markdown]
# ---

# %%
vis4 = sns.lmplot(data = stats, x = 'InternerUsers', y = 'BirthRate')

# %%
vis4 = sns.lmplot(data = stats, x = 'InternerUsers', y = 'BirthRate', 
                  hue= 'IncomeGroup',fit_reg= False, height = 8)

# %% [markdown]
# ---

# %%
###Marker Size

# %%
vis4 = sns.lmplot(data = stats, x = 'InternerUsers', y = 'BirthRate', 
                  hue= 'IncomeGroup',fit_reg= False, height = 8, scatter_kws={'s': 150} )
